# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

x = range(296)
inside = pd.read_csv('weather_data_inside.csv')[1::]
outside = pd.read_csv('weather_quality_outside.csv')[60:361]

fig = plt.figure()
ax1 = plt.axes()

ax1.plot(x, inside['PM1.0'], label = 'PM1.0 for inside data', ls = '--', c = 'r')
ax1.plot(x, outside['PM1.0'], label = 'PM1.0 for outside data', ls = '-.', c = 'b')
ax1.set(xlabel = 'Time (s)', ylabel = 'AQI (PM 1.0)', title = 'Comparing PM1.0 Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax1)

# %%
fig = plt.figure()
ax2 = plt.axes()

ax2.plot(x, inside['PM2.5'], label = 'PM2.5 for inside data', ls = '--', c = 'r')
ax2.plot(x, outside['PM2.5'], label = 'PM2.5 for outside data', ls = '-.', c = 'b')
ax2.set(xlabel = 'Time (s)', ylabel = 'AQI (PM 2.5)', title = 'Comparing PM2.5 Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax2)

# %%
fig = plt.figure()
ax3 = plt.axes()

ax3.plot(x, inside['PM10'], label = 'PM10 for inside data', ls = '--', c = 'r')
ax3.plot(x, outside['PM10'], label = 'PM10 for outside data', ls = '-.', c = 'b')
ax3.set(xlabel = 'Time (s)', ylabel = 'AQI (PM 10)', title = 'Comparing PM10 Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax3)

# %%
fig = plt.figure()
ax4 = plt.axes()

ax4.plot(x, inside['Temperature'], label = 'Temperature for inside data', ls = '--', c = 'r')
ax4.plot(x, outside['Temperature'], label = 'Temperature for outside data', ls = '-.', c = 'b')
ax4.set(xlabel = 'Time (s)', ylabel = 'Temperature(C)', title = 'Comparing Temperature Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax4)

# %%
fig = plt.figure()
ax5 = plt.axes()

ax5.plot(x, inside['Gas'], label = 'Gas for inside data', ls = '--', c = 'r')
ax5.plot(x, outside['Gas'], label = 'Gas for outside data', ls = '-.', c = 'b')
ax5.set(xlabel = 'Time (s)', ylabel = 'Gas(Ohms)', title = 'Comparing Gas Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax5)

# %%
fig = plt.figure()
ax6 = plt.axes()

ax6.plot(x, inside['Relative Humidity'], label = 'Relative Humidity for inside data', ls = '--', c = 'r')
ax6.plot(x, outside['Relative Humidity'], label = 'Relative Humidity for outside data', ls = '-.', c = 'b')
ax6.set(xlabel = 'Time (s)', ylabel = 'Percent Relative Humidity(%)', title = 'Comparing Relative Humidity Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax6)

# %%
fig = plt.figure()
ax7 = plt.axes()

ax7.plot(x, inside['Pressure'], label = 'Pressure for inside data', ls = '--', c = 'r')
ax7.plot(x, outside['Pressure'], label = 'Pressure for outside data', ls = '-.', c = 'b')
ax7.set(xlabel = 'Time (s)', ylabel = 'Pressure(Torr)', title = 'Comparing Pressure Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax7)

# %%
fig = plt.figure()
ax8 = plt.axes()

ax8.plot(x, inside['Altitude'], label = 'Altitude for inside data', ls = '--', c = 'r')
ax8.plot(x, outside['Altitude'], label = 'Altitude for outside data', ls = '-.', c = 'b')
ax8.set(xlabel = 'Time (s)', ylabel = 'Altitude(m)', title = 'Comparing Pressure Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax8)

# %%
fig = plt.figure()
ax1 = plt.axes()

ax1.hist(inside['PM1.0'], label = 'PM1.0 for inside data', bins = 4, color = 'b')
ax1.hist(outside['PM1.0'], label = 'PM1.0 for outside data', bins = 5, color = 'r', alpha = 0.7)
ax1.set(xlabel = r'$\mu/m^3$', ylabel = 'Counts', title = 'Comparing PM1.0 Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax1)

# %%
fig = plt.figure()
ax2 = plt.axes()

ax2.hist(inside['PM2.5'], label = 'PM2.5 for inside data', bins = 4, color = 'b')
ax2.hist(outside['PM2.5'], label = 'PM2.5 for outside data', bins = 8, color = 'r', alpha = 0.7)
ax2.set(xlabel = r'$\mu/m^3$', ylabel = 'Counts', title = 'Comparing PM2.5 Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax2)

# %%
fig = plt.figure()
ax3 = plt.axes()

ax3.hist(inside['PM10'], label = 'PM10 for inside data', bins = 4, color = 'b')
ax3.hist(outside['PM10'], label = 'PM10 for outside data', bins = 9, color = 'r', alpha = 0.7)
ax3.set(xlabel = r'$\mu/m^3$', ylabel = 'Counts', title = 'Comparing PM10 Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax3)

# %%
fig = plt.figure()
ax4 = plt.axes()

ax4.hist(inside['Temperature'], label = 'Temperature for inside data', bins = 50, color = 'b')
ax4.hist(outside['Temperature'], label = 'Temperature for outside data', bins = 62, color = 'r', alpha = 0.7)
ax4.set(xlabel = r'Temperature $^\circ$C', ylabel = 'Counts', title = 'Comparing Temperature Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax4)

# %%
fig = plt.figure()
ax5 = plt.axes()

ax5.hist(inside['Gas'], label = 'Gas for inside data', bins = 60, color = 'b')
ax5.hist(outside['Gas'], label = 'Gas for outside data', bins = 60, color = 'r', alpha = 0.7)
ax5.set(xlabel = r'Gas $\Omega$', ylabel = 'Counts', title = 'Comparing Gas Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax5)

# %%
fig = plt.figure()
ax6 = plt.axes()

ax6.hist(inside['Relative Humidity'], label = 'Relative humidity for inside data', bins = 25, color = 'b')
ax6.hist(outside['Relative Humidity'], label = 'Relative humidity for outside data', bins = 25, color = 'r', alpha = 0.7)
ax6.set(xlabel = '% humidity', ylabel = 'Counts', title = 'Comparing Humidity Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax6)

# %%
fig = plt.figure()
ax7 = plt.axes()

ax7.hist(inside['Pressure'], label = 'Pressure for inside data', bins = 25, color = 'b')
ax7.hist(outside['Pressure'], label = 'Pressure for outside data', bins = 25, color = 'r', alpha = 0.7)
ax7.set(xlabel = 'Torr', ylabel = 'Counts', title = 'Comparing Pressure Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax7)

# %%
fig = plt.figure()
ax8 = plt.axes()

ax8.hist(inside['Altitude'], label = 'Altitude for inside data', bins = 5, color = 'b')
ax8.hist(outside['Altitude'], label = 'Altitude for outside data', bins = 50, color = 'r', alpha = 0.7)
ax8.set(xlabel = 'Altitude (m)', ylabel = 'Counts', title = 'Comparing Altitude Data for Inside and Outside over 300s')

plt.legend()
plt.show(ax8)

# %%
insidepm1 = np.std(inside['PM1.0'])/np.sqrt(sum(inside['PM1.0']))

outsidepm1 = np.std(outside['PM1.0'])/np.sqrt(sum(outside['PM1.0']))

sigmapm1 = np.sqrt((insidepm1**2 + outsidepm1**2)/2)

within3sigpm1 = math.isclose(np.mean(inside['PM1.0']), np.mean(outside['PM1.0']), rel_tol = 3*sigmaom1)

print(f'The argument that the means of PM1.0 are within 3 sigma of eachother is {within3sigpm1}')
# Out:
# The argument that the means of PM1.0 are within 3 sigma of eachother is False

# %%
insidepm2 = np.std(inside['PM2.5'])/sum(inside['PM2.5'])

outsidepm2 = np.std(outside['PM2.5'])/sum(outside['PM2.5'])

sigmapm2 = np.sqrt((insidepm2**2 + outsidepm2**2)/2)

within3sigpm2 = math.isclose(np.mean(inside['PM2.5']), np.mean(outside['PM2.5']), rel_tol = 3*sigmapm2)

print(f'The argument that the means of PM2.5 are within 3 sigma of eachother is {within3sigpm2}')
# Out:
# The argument that the means of PM2.5 are within 3 sigma of eachother is False

# %%
insidepm10 = np.std(inside['PM10'])/sum(inside['PM10'])

outsidepm10 = np.std(outside['PM10'])/sum(outside['PM10'])

sigma10 = np.sqrt((insidepm10**2 + outsidepm10**2)/2)

within3sigpm10 = math.isclose(np.mean(inside['PM10']), np.mean(outside['PM10']), rel_tol = 3*sigma10)

print(f'The argument that the means of PM10 are within 3 sigma of eachother is {within3sigpm10}')
# Out:
# The argument that the means of PM10 are within 3 sigma of eachother is False

# %%
insideTemp = np.std(inside['Temperature'])/sum(inside['Temperature'])

outsideTemp = np.std(outside['Temperature'])/sum(outside['Temperature'])

sigmaTemp = np.sqrt((insideTemp**2 + outsideTemp**2)/2)

within3sigTemp = math.isclose(np.mean(inside['Temperature']), np.mean(outside['Temperature']), rel_tol = 3*sigmaTemp)

print(f'The argument that the means of temperature are within 3 sigma of eachother is {within3sigTemp}')
# Out:
# The argument that the means of Temperature are within 3 sigma of eachother is False

# %%
insideGas = np.std(inside['Gas'])/sum(inside['Gas'])

outsideGas = np.std(outside['Gas'])/sum(outside['Gas'])

sigmaGas = np.sqrt((insideGas**2 + outsideGas**2)/2)

within3sigGas = math.isclose(np.mean(inside['Gas']), np.mean(outside['Gas']), rel_tol = 3*sigmaGas)

print(f'The argument that the means of gas are within 3 sigma of eachother is {within3sigGas}')
# Out:
# The argument that the means of Temperature are within 3 sigma of eachother is False

# %%
insideHumidity = np.std(inside['Relative Humidity'])/sum(inside['Relative Humidity'])

outsideHumidity = np.std(outside['Relative Humidity'])/sum(outside['Relative Humidity'])

sigmaHumidity = np.sqrt((insideHumidity**2 + outsideHumidity**2)/2)

within3sigHumidity = math.isclose(np.mean(inside['Relative Humidity']), np.mean(outside['Relative Humidity']), rel_tol = 3*sigmaHumidity)

print(f'The argument that the means of relative humidity are within 3 sigma of eachother is {within3sigHumidity}')
# Out:
# The argument that the means of Temperature are within 3 sigma of eachother is False

# %%
insidePressure = np.std(inside['Pressure'])/sum(inside['Pressure'])

outsidePressure = np.std(outside['Pressure'])/sum(outside['Pressure'])

sigmaPressure = np.sqrt((insidePressure**2 + outsidePressure**2)/2)

within3sigPressure = math.isclose(np.mean(inside['Pressure']), np.mean(outside['Pressure']), rel_tol = 3*sigmaPressure)

print(f'The argument that the means of pressure are within 3 sigma of eachother is {within3sigPressure}')
# Out:
# The argument that the means of Temperature are within 3 sigma of eachother is False

# %%
insideAlt = np.std(inside['Altitude'])/sum(inside['Altitude'])

outsideAlt = np.std(outside['Altitude'])/sum(outside['Altitude'])

sigmaAlt = np.sqrt((insideAlt**2 + outsideAlt**2)/2)

within3sigAlt = math.isclose(np.mean(inside['Altitude']), np.mean(outside['Altitude']), rel_tol = 3*sigmaAlt)

print(f'The argument that the means of altitude are within 3 sigma of eachother is {within3sigAlt}')
# Out:
# The argument that the means of Temperature are within 3 sigma of eachother is False

# %% [markdown]
# From this we can tell that for all sets of data the data indoors and outdoors is meaningfully different. Looking at either the time series or the histograms shows this relatively obviously as well.
